# %%
import pandas as df
import requests

# %%
api_url = "https://www.waterqualitydata.us/ogcservices/wfs/?request=GetFeature&service=wfs&version=2.0.0&typeNames=wqp_sites&SEARCHPARAMS=countrycode%3AUS%3Bstatecode%3AUS%3A04%3Bcountycode%3AUS%3A04%3A013%3BsiteType%3ALake%2C%20Reservoir%2C%20Impoundment%3BsampleMedia%3Awater%7CWater&outputFormat=application%2Fjson"

response = requests.get(api_url).json()

# %%
response
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': 'dynamicSites_2656510689.1',
#    'geometry': {'type': 'Point', 'coordinates': [-111.71375, 33.601155]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'USGS-AZ',
#     'orgName': 'USGS Arizona Water Science Center',
#     'name': 'USGS-333604111424700',
#     'locName': 'FOUNTAIN LAKE IN FOUNTAIN HILLS',
#     'type': 'Lake, Reservoir, Impoundment',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'NWIS',
#     'sampleCnt': '2',
#     'resultCnt': '250',
#     'bbox': [-111.71375, 33.601155, -111.71375, 33.601155]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.2',
#    'geometry': {'type': 'Point', 'coordinates': [-112.2684949, 33.8539238]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'USGS-AZ',
#     'orgName': 'USGS Arizona Water Science Center',
#     'name': 'USGS-335114112160401',
#     'locName': 'LAKE PLEASANT NEAR DAM',
#     'type': 'Lake, Reservoir, Impoundment',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070102',
#     'provider': 'NWIS',
#     'sampleCnt': '2',
#     'resultCnt': '139',
#     'bbox': [-112.2684949, 33.8539238, -112.2684949, 33.8539238]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.3',
#    'geometry': {'type': 'Point', 'coordinates': [-112.2698839, 33.856146]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'USGS-AZ',
#     'orgName': 'USGS Arizona Water Science Center',
#     'name': 'USGS-335122112160900',
#     'locName': 'LK PLEASANT 0.3 KM ABV WADDELL DAM',
#     'type': 'Lake, Reservoir, Impoundment',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070102',
#     'provider': 'NWIS',
#     'sampleCnt': '4',
#     'resultCnt': '304',
#     'bbox': [-112.2698839, 33.856146, -112.2698839, 33.856146]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.4',
#    'geometry': {'type': 'Point', 'coordinates': [-111.23738, 33.5905183]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100008',
#     'locName': 'SRAPA-E',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '34',
#     'resultCnt': '330',
#     'bbox': [-111.23738, 33.5905183, -111.23738, 33.5905183]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.5',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6258333, 33.8208333]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100009',
#     'locName': 'VRBAR-A',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '568',
#     'resultCnt': '5658',
#     'bbox': [-111.6258333, 33.8208333, -111.6258333, 33.8208333]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.6',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6175, 33.8525]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100010',
#     'locName': 'VRBAR-B',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '344',
#     'resultCnt': '3250',
#     'bbox': [-111.6175, 33.8525, -111.6175, 33.8525]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.7',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6419433, 33.89361]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100011',
#     'locName': 'VRBAR-C',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '241',
#     'resultCnt': '2359',
#     'bbox': [-111.6419433, 33.89361, -111.6419433, 33.89361]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.8',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6217183, 33.83026]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100012',
#     'locName': 'VRBAR-D',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '10',
#     'resultCnt': '83',
#     'bbox': [-111.6217183, 33.83026, -111.6217183, 33.83026]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.9',
#    'geometry': {'type': 'Point', 'coordinates': [-113.0213916, 33.0819233]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100050',
#     'locName': 'CLPRL-B',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070201',
#     'provider': 'STORET',
#     'sampleCnt': '10',
#     'resultCnt': '77',
#     'bbox': [-113.0213916, 33.0819233, -113.0213916, 33.0819233]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.10',
#    'geometry': {'type': 'Point', 'coordinates': [-113.0213916, 33.0819233]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100051',
#     'locName': 'CLPRL-C',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070201',
#     'provider': 'STORET',
#     'sampleCnt': '3',
#     'resultCnt': '9',
#     'bbox': [-113.0213916, 33.0819233, -113.0213916, 33.0819233]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.11',
#    'geometry': {'type': 'Point', 'coordinates': [-112.2641666, 33.8502766]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100067',
#     'locName': 'MGPLE-A',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070102',
#     'provider': 'STORET',
#     'sampleCnt': '359',
#     'resultCnt': '2979',
#     'bbox': [-112.2641666, 33.8502766, -112.2641666, 33.8502766]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.12',
#    'geometry': {'type': 'Point', 'coordinates': [-112.2419433, 33.90611]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100068',
#     'locName': 'MGPLE-B',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070102',
#     'provider': 'STORET',
#     'sampleCnt': '203',
#     'resultCnt': '1714',
#     'bbox': [-112.2419433, 33.90611, -112.2419433, 33.90611]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.13',
#    'geometry': {'type': 'Point', 'coordinates': [-111.15361, 33.6769433]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100075',
#     'locName': 'SRROO-A',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060103',
#     'provider': 'STORET',
#     'sampleCnt': '284',
#     'resultCnt': '2747',
#     'bbox': [-111.15361, 33.6769433, -111.15361, 33.6769433]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.14',
#    'geometry': {'type': 'Point', 'coordinates': [-111.515555, 33.5722216]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100081',
#     'locName': 'SRSAG-BJ',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '56',
#     'resultCnt': '535',
#     'bbox': [-111.515555, 33.5722216, -111.515555, 33.5722216]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.15',
#    'geometry': {'type': 'Point', 'coordinates': [-111.5358333, 33.5675]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100082',
#     'locName': 'SRSAG-A',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '292',
#     'resultCnt': '2723',
#     'bbox': [-111.5358333, 33.5675, -111.5358333, 33.5675]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.16',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6172216, 33.8466666]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100980',
#     'locName': 'VRBAR-NTU1',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '1',
#     'resultCnt': '1',
#     'bbox': [-111.6172216, 33.8466666, -111.6172216, 33.8466666]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.17',
#    'geometry': {'type': 'Point', 'coordinates': [-111.60111, 33.8644433]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100981',
#     'locName': 'VRBAR-NTU2',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '4',
#     'resultCnt': '4',
#     'bbox': [-111.60111, 33.8644433, -111.60111, 33.8644433]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.18',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6141666, 33.8675]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100982',
#     'locName': 'VRBAR-NTU3',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '32',
#     'resultCnt': '238',
#     'bbox': [-111.6141666, 33.8675, -111.6141666, 33.8675]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.19',
#    'geometry': {'type': 'Point', 'coordinates': [-111.610555, 33.8825]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100983',
#     'locName': 'VRBAR-NTU4',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '27',
#     'resultCnt': '188',
#     'bbox': [-111.610555, 33.8825, -111.610555, 33.8825]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.20',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6244433, 33.8847216]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100984',
#     'locName': 'VRBAR-NTU5',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '10',
#     'resultCnt': '73',
#     'bbox': [-111.6244433, 33.8847216, -111.6244433, 33.8847216]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.21',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6344433, 33.8313883]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100986',
#     'locName': 'VRBAR-MAR1',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '7',
#     'resultCnt': '35',
#     'bbox': [-111.6344433, 33.8313883, -111.6344433, 33.8313883]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.22',
#    'geometry': {'type': 'Point', 'coordinates': [-111.5372216, 33.5713883]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100994',
#     'locName': 'SRSAG-MAR1',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '14',
#     'resultCnt': '60',
#     'bbox': [-111.5372216, 33.5713883, -111.5372216, 33.5713883]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.23',
#    'geometry': {'type': 'Point', 'coordinates': [-111.5344433, 33.57361]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100995',
#     'locName': 'SRSAG-MAR2',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '7',
#     'resultCnt': '82',
#     'bbox': [-111.5344433, 33.57361, -111.5344433, 33.57361]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.24',
#    'geometry': {'type': 'Point', 'coordinates': [-111.3419433, 33.5913883]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100997',
#     'locName': 'SRAPA-A',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '279',
#     'resultCnt': '2253',
#     'bbox': [-111.3419433, 33.5913883, -111.3419433, 33.5913883]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.25',
#    'geometry': {'type': 'Point', 'coordinates': [-111.2588883, 33.5813883]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-100998',
#     'locName': 'SRAPA-MAR',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '18',
#     'resultCnt': '145',
#     'bbox': [-111.2588883, 33.5813883, -111.2588883, 33.5813883]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.26',
#    'geometry': {'type': 'Point', 'coordinates': [-112.2675, 33.8547216]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101000',
#     'locName': 'MGPLE-MAR',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070102',
#     'provider': 'STORET',
#     'sampleCnt': '28',
#     'resultCnt': '169',
#     'bbox': [-112.2675, 33.8547216, -112.2675, 33.8547216]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.27',
#    'geometry': {'type': 'Point', 'coordinates': [-111.4869433, 33.5747216]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101001',
#     'locName': 'SRSAG-BAG',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '8',
#     'resultCnt': '107',
#     'bbox': [-111.4869433, 33.5747216, -111.4869433, 33.5747216]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.28',
#    'geometry': {'type': 'Point', 'coordinates': [-112.1375, 33.375]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101040',
#     'locName': 'MGALV-A',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '94',
#     'resultCnt': '681',
#     'bbox': [-112.1375, 33.375, -112.1375, 33.375]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.29',
#    'geometry': {'type': 'Point', 'coordinates': [-112.1375, 33.3741666]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101041',
#     'locName': 'MGALV-B',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '60',
#     'resultCnt': '355',
#     'bbox': [-112.1375, 33.3741666, -112.1375, 33.3741666]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.30',
#    'geometry': {'type': 'Point', 'coordinates': [-112.135555, 33.3741666]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101042',
#     'locName': 'MGALV-C',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '97',
#     'resultCnt': '525',
#     'bbox': [-112.135555, 33.3741666, -112.135555, 33.3741666]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.31',
#    'geometry': {'type': 'Point', 'coordinates': [-112.1183333, 33.570555]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101043',
#     'locName': 'MGCOR-A',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070102',
#     'provider': 'STORET',
#     'sampleCnt': '27',
#     'resultCnt': '371',
#     'bbox': [-112.1183333, 33.570555, -112.1183333, 33.570555]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.32',
#    'geometry': {'type': 'Point', 'coordinates': [-112.1316666, 33.57]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101044',
#     'locName': 'MGCOR-B',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070102',
#     'provider': 'STORET',
#     'sampleCnt': '15',
#     'resultCnt': '225',
#     'bbox': [-112.1316666, 33.57, -112.1316666, 33.57]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.33',
#    'geometry': {'type': 'Point', 'coordinates': [-111.9069433, 33.5113883]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101045',
#     'locName': 'MGCHA-A',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '72',
#     'resultCnt': '554',
#     'bbox': [-111.9069433, 33.5113883, -111.9069433, 33.5113883]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.34',
#    'geometry': {'type': 'Point', 'coordinates': [-111.9075, 33.5133333]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101046',
#     'locName': 'MGCHA-B',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '58',
#     'resultCnt': '338',
#     'bbox': [-111.9075, 33.5133333, -111.9075, 33.5133333]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.35',
#    'geometry': {'type': 'Point', 'coordinates': [-111.9475, 33.4525]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101047',
#     'locName': 'MGPAP-A',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '63',
#     'resultCnt': '445',
#     'bbox': [-111.9475, 33.4525, -111.9475, 33.4525]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.36',
#    'geometry': {'type': 'Point', 'coordinates': [-111.9466666, 33.453055]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101048',
#     'locName': 'MGPAP-B',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '39',
#     'resultCnt': '227',
#     'bbox': [-111.9466666, 33.453055, -111.9466666, 33.453055]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.37',
#    'geometry': {'type': 'Point', 'coordinates': [-112.1352766, 33.3763883]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101053',
#     'locName': 'MGALV-ABC',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '41',
#     'resultCnt': '102',
#     'bbox': [-112.1352766, 33.3763883, -112.1352766, 33.3763883]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.38',
#    'geometry': {'type': 'Point', 'coordinates': [-112.1291666, 33.5713883]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101055',
#     'locName': 'MGCOR-AB',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070102',
#     'provider': 'STORET',
#     'sampleCnt': '39',
#     'resultCnt': '103',
#     'bbox': [-112.1291666, 33.5713883, -112.1291666, 33.5713883]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.39',
#    'geometry': {'type': 'Point', 'coordinates': [-111.9044433, 33.5083333]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101056',
#     'locName': 'MGCHA-AB',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '23',
#     'resultCnt': '100',
#     'bbox': [-111.9044433, 33.5083333, -111.9044433, 33.5083333]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.40',
#    'geometry': {'type': 'Point', 'coordinates': [-111.95111, 33.4502766]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101057',
#     'locName': 'MGPAP-AB',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '38',
#     'resultCnt': '100',
#     'bbox': [-111.95111, 33.4502766, -111.95111, 33.4502766]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.41',
#    'geometry': {'type': 'Point', 'coordinates': [-111.9183333, 33.433055]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101315',
#     'locName': 'MGTTL-B',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '33',
#     'resultCnt': '271',
#     'bbox': [-111.9183333, 33.433055, -111.9183333, 33.433055]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.42',
#    'geometry': {'type': 'Point', 'coordinates': [-111.9463883, 33.4333333]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101316',
#     'locName': 'MGTTL-A',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '49',
#     'resultCnt': '483',
#     'bbox': [-111.9463883, 33.4333333, -111.9463883, 33.4333333]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.43',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6244433, 33.82]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101321',
#     'locName': 'VRBAR-SW',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '1',
#     'resultCnt': '1',
#     'bbox': [-111.6244433, 33.82, -111.6244433, 33.82]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.44',
#    'geometry': {'type': 'Point', 'coordinates': [-111.4422216, 33.5527766]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101697',
#     'locName': 'SRCAN-A',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '152',
#     'resultCnt': '1346',
#     'bbox': [-111.4422216, 33.5527766, -111.4422216, 33.5527766]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.45',
#    'geometry': {'type': 'Point', 'coordinates': [-111.48479, 33.57204]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101698',
#     'locName': 'SRSAG-MFLAT',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '9',
#     'resultCnt': '54',
#     'bbox': [-111.48479, 33.57204, -111.48479, 33.57204]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.46',
#    'geometry': {'type': 'Point', 'coordinates': [-111.3783333, 33.578055]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101699',
#     'locName': 'SRCAN-B',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '65',
#     'resultCnt': '591',
#     'bbox': [-111.3783333, 33.578055, -111.3783333, 33.578055]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.47',
#    'geometry': {'type': 'Point', 'coordinates': [-111.4117383, 33.5574383]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101700',
#     'locName': 'SRCAN-CG1',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '3',
#     'resultCnt': '3',
#     'bbox': [-111.4117383, 33.5574383, -111.4117383, 33.5574383]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.48',
#    'geometry': {'type': 'Point', 'coordinates': [-111.42425, 33.5360083]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101701',
#     'locName': 'SRCAN-MAR',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '3',
#     'resultCnt': '3',
#     'bbox': [-111.42425, 33.5360083, -111.42425, 33.5360083]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.49',
#    'geometry': {'type': 'Point', 'coordinates': [-111.25672, 33.57399]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101704',
#     'locName': 'SRAPA-BCH',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '2',
#     'resultCnt': '4',
#     'bbox': [-111.25672, 33.57399, -111.25672, 33.57399]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.50',
#    'geometry': {'type': 'Point', 'coordinates': [-111.1691666, 33.6672216]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101706',
#     'locName': 'SRAPA-C',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '49',
#     'resultCnt': '421',
#     'bbox': [-111.1691666, 33.6672216, -111.1691666, 33.6672216]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.51',
#    'geometry': {'type': 'Point', 'coordinates': [-111.20439, 33.62477]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101707',
#     'locName': 'SRAPA-BC',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '3',
#     'resultCnt': '3',
#     'bbox': [-111.20439, 33.62477, -111.20439, 33.62477]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.52',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6363883, 33.83385]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101709',
#     'locName': 'VRBAR-MAR',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '3',
#     'resultCnt': '5',
#     'bbox': [-111.6363883, 33.83385, -111.6363883, 33.83385]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.53',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6301, 33.83385]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101710',
#     'locName': 'VRBAR-CG2',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '4',
#     'resultCnt': '8',
#     'bbox': [-111.6301, 33.83385, -111.6301, 33.83385]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.54',
#    'geometry': {'type': 'Point', 'coordinates': [-111.2319433, 33.59611]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101712',
#     'locName': 'SRAPA-B',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '94',
#     'resultCnt': '807',
#     'bbox': [-111.2319433, 33.59611, -111.2319433, 33.59611]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.55',
#    'geometry': {'type': 'Point', 'coordinates': [-111.4472216, 33.55611]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-101810',
#     'locName': 'SRSAG-C',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '89',
#     'resultCnt': '725',
#     'bbox': [-111.4472216, 33.55611, -111.4472216, 33.55611]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.56',
#    'geometry': {'type': 'Point', 'coordinates': [-111.933055, 33.4325]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102452',
#     'locName': 'MGTTL-MID',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '2',
#     'resultCnt': '20',
#     'bbox': [-111.933055, 33.4325, -111.933055, 33.4325]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.57',
#    'geometry': {'type': 'Point', 'coordinates': [-113.0247216, 33.0797216]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102515',
#     'locName': 'CLPRL-D',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070201',
#     'provider': 'STORET',
#     'sampleCnt': '4',
#     'resultCnt': '11',
#     'bbox': [-113.0247216, 33.0797216, -113.0247216, 33.0797216]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.58',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6169433, 33.8822216]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102536',
#     'locName': 'VRBAR-FLAT',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '2',
#     'resultCnt': '28',
#     'bbox': [-111.6169433, 33.8822216, -111.6169433, 33.8822216]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.59',
#    'geometry': {'type': 'Point', 'coordinates': [-111.34611, 33.5902766]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102538',
#     'locName': 'SRCAN-1',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '22',
#     'resultCnt': '107',
#     'bbox': [-111.34611, 33.5902766, -111.34611, 33.5902766]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.60',
#    'geometry': {'type': 'Point', 'coordinates': [-112.1933333, 33.4752766]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102543',
#     'locName': 'MGDSW-B',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070102',
#     'provider': 'STORET',
#     'sampleCnt': '3',
#     'resultCnt': '12',
#     'bbox': [-112.1933333, 33.4752766, -112.1933333, 33.4752766]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.61',
#    'geometry': {'type': 'Point', 'coordinates': [-112.1927766, 33.47611]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102544',
#     'locName': 'MGDSW-E',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070102',
#     'provider': 'STORET',
#     'sampleCnt': '6',
#     'resultCnt': '60',
#     'bbox': [-112.1927766, 33.47611, -112.1927766, 33.47611]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.62',
#    'geometry': {'type': 'Point', 'coordinates': [-112.19361, 33.4747216]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102545',
#     'locName': 'MGDSW-W',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070102',
#     'provider': 'STORET',
#     'sampleCnt': '6',
#     'resultCnt': '63',
#     'bbox': [-112.19361, 33.4747216, -112.19361, 33.4747216]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.63',
#    'geometry': {'type': 'Point', 'coordinates': [-111.4927766, 33.5772216]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102559',
#     'locName': 'SRSAG-2',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '10',
#     'resultCnt': '39',
#     'bbox': [-111.4927766, 33.5772216, -111.4927766, 33.5772216]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.64',
#    'geometry': {'type': 'Point', 'coordinates': [-112.1363883, 33.37611]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102562',
#     'locName': 'MGALV-EAST',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '10',
#     'resultCnt': '51',
#     'bbox': [-112.1363883, 33.37611, -112.1363883, 33.37611]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.65',
#    'geometry': {'type': 'Point', 'coordinates': [-112.135555, 33.373055]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102563',
#     'locName': 'MGALV-WEST',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '11',
#     'resultCnt': '51',
#     'bbox': [-112.135555, 33.373055, -112.135555, 33.373055]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.66',
#    'geometry': {'type': 'Point', 'coordinates': [-111.34861, 33.5875]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102615',
#     'locName': 'SRCAN-C1',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '4',
#     'resultCnt': '24',
#     'bbox': [-111.34861, 33.5875, -111.34861, 33.5875]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.67',
#    'geometry': {'type': 'Point', 'coordinates': [-112.1356933, 33.3735833]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102752',
#     'locName': 'MGALVALV-BR',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '2',
#     'resultCnt': '11',
#     'bbox': [-112.1356933, 33.3735833, -112.1356933, 33.3735833]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.68',
#    'geometry': {'type': 'Point', 'coordinates': [-111.2061666, 33.6353333]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102753',
#     'locName': 'SRAPA-COR',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '24',
#     'resultCnt': '225',
#     'bbox': [-111.2061666, 33.6353333, -111.2061666, 33.6353333]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.69',
#    'geometry': {'type': 'Point', 'coordinates': [-111.4312766, 33.5511666]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102754',
#     'locName': 'SRCAN-CAN',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '2',
#     'resultCnt': '23',
#     'bbox': [-111.4312766, 33.5511666, -111.4312766, 33.5511666]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.70',
#    'geometry': {'type': 'Point', 'coordinates': [-112.0872216, 33.4763883]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102757',
#     'locName': 'MGENC-B',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '4',
#     'resultCnt': '26',
#     'bbox': [-112.0872216, 33.4763883, -112.0872216, 33.4763883]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.71',
#    'geometry': {'type': 'Point', 'coordinates': [-111.7170266, 33.98686]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102758',
#     'locName': 'VRHSR-BR',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '2',
#     'resultCnt': '14',
#     'bbox': [-111.7170266, 33.98686, -111.7170266, 33.98686]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.72',
#    'geometry': {'type': 'Point', 'coordinates': [-111.93861, 33.3741666]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102759',
#     'locName': 'MGKIW-B',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '2',
#     'resultCnt': '8',
#     'bbox': [-111.93861, 33.3741666, -111.93861, 33.3741666]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.73',
#    'geometry': {'type': 'Point', 'coordinates': [-111.4168683, 33.5592583]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102837',
#     'locName': 'SRCAN-MID',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '2',
#     'resultCnt': '29',
#     'bbox': [-111.4168683, 33.5592583, -111.4168683, 33.5592583]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.74',
#    'geometry': {'type': 'Point', 'coordinates': [-111.7366666, 33.363055]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102839',
#     'locName': 'MGWTR-MID',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15050100',
#     'provider': 'STORET',
#     'sampleCnt': '2',
#     'resultCnt': '12',
#     'bbox': [-111.7366666, 33.363055, -111.7366666, 33.363055]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.75',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6669433, 33.4347216]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-102840',
#     'locName': 'MGRDM-MID',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15050100',
#     'provider': 'STORET',
#     'sampleCnt': '2',
#     'resultCnt': '18',
#     'bbox': [-111.6669433, 33.4347216, -111.6669433, 33.4347216]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.76',
#    'geometry': {'type': 'Point', 'coordinates': [-112.1319433, 33.5698883]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-103351',
#     'locName': 'MGCOR-SH',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070102',
#     'provider': 'STORET',
#     'sampleCnt': '1',
#     'resultCnt': '3',
#     'bbox': [-112.1319433, 33.5698883, -112.1319433, 33.5698883]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.77',
#    'geometry': {'type': 'Point', 'coordinates': [-111.48193, 33.56315]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ',
#     'orgName': 'Arizona Department of Environmental Quality',
#     'name': '21ARIZ-104397',
#     'locName': 'SRSAG-B',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '7',
#     'resultCnt': '42',
#     'bbox': [-111.48193, 33.56315, -111.48193, 33.56315]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.78',
#    'geometry': {'type': 'Point', 'coordinates': [-112.1383333, 33.375]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-MGALV-A',
#     'locName': 'ALVORD PARK LAKE - INFLOW',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '7',
#     'resultCnt': '95',
#     'bbox': [-112.1383333, 33.375, -112.1383333, 33.375]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.79',
#    'geometry': {'type': 'Point', 'coordinates': [-112.1363889, 33.3741667]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-MGALV-C',
#     'locName': 'ALVORD PARK LAKE - MID LAKE',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '25',
#     'resultCnt': '221',
#     'bbox': [-112.1363889, 33.3741667, -112.1363889, 33.3741667]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.80',
#    'geometry': {'type': 'Point', 'coordinates': [-112.1363889, 33.3730556]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-MGALV-WEST',
#     'locName': 'ALVORD LAKE - WEST LAGOON',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '39',
#     'resultCnt': '337',
#     'bbox': [-112.1363889, 33.3730556, -112.1363889, 33.3730556]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.81',
#    'geometry': {'type': 'Point', 'coordinates': [-111.9077778, 33.5113889]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-MGCHA-A',
#     'locName': 'CHAPARRAL PARK LAKE - AT DAM',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '27',
#     'resultCnt': '242',
#     'bbox': [-111.9077778, 33.5113889, -111.9077778, 33.5113889]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.82',
#    'geometry': {'type': 'Point', 'coordinates': [-111.9083333, 33.5133333]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-MGCHA-B',
#     'locName': 'CHAPARRAL PARK LAKE - MID LAKE',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '31',
#     'resultCnt': '285',
#     'bbox': [-111.9083333, 33.5133333, -111.9083333, 33.5133333]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.83',
#    'geometry': {'type': 'Point', 'coordinates': [-112.1191667, 33.5705556]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-MGCOR-A',
#     'locName': 'CORTEZ PARK LAKE - AT DAM',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070102',
#     'provider': 'STORET',
#     'sampleCnt': '29',
#     'resultCnt': '253',
#     'bbox': [-112.1191667, 33.5705556, -112.1191667, 33.5705556]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.84',
#    'geometry': {'type': 'Point', 'coordinates': [-112.1325, 33.57]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-MGCOR-B',
#     'locName': 'CORTEZ PARK LAKE - MID LAKE',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070102',
#     'provider': 'STORET',
#     'sampleCnt': '29',
#     'resultCnt': '251',
#     'bbox': [-112.1325, 33.57, -112.1325, 33.57]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.85',
#    'geometry': {'type': 'Point', 'coordinates': [-112.265, 33.8502778]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-MGPLE-A',
#     'locName': 'LAKE PLEASANT - AT DAM',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070102',
#     'provider': 'STORET',
#     'sampleCnt': '62',
#     'resultCnt': '310',
#     'bbox': [-112.265, 33.8502778, -112.265, 33.8502778]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.86',
#    'geometry': {'type': 'Point', 'coordinates': [-111.9205306, 33.3763583]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-MGTEM-NLS',
#     'locName': 'TEMPE, THE LAKES - MID LAKE',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '3',
# ...
#     'provider': 'STORET',
#     'sampleCnt': '19',
#     'resultCnt': '144',
#     'bbox': [-111.3788889, 33.5780556, -111.3788889, 33.5780556]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.93',
#    'geometry': {'type': 'Point', 'coordinates': [-111.3491667, 33.5875]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-SRCAN-C1',
#     'locName': 'CANYON LAKE - AT INLET',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '36',
#     'resultCnt': '271',
#     'bbox': [-111.3491667, 33.5875, -111.3491667, 33.5875]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.94',
#    'geometry': {'type': 'Point', 'coordinates': [-111.4230111, 33.5372333]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-SRCAN-RL',
#     'locName': 'CANYON LAKE - ACROSS FROM RESTAURANT LOUNGE',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '117',
#     'resultCnt': '997',
#     'bbox': [-111.4230111, 33.5372333, -111.4230111, 33.5372333]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.95',
#    'geometry': {'type': 'Point', 'coordinates': [-111.4014333, 33.5594889]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-SRCAN-STE',
#     'locName': 'CANYON LAKE - AT STEEP CLIFFS',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '64',
#     'resultCnt': '423',
#     'bbox': [-111.4014333, 33.5594889, -111.4014333, 33.5594889]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.96',
#    'geometry': {'type': 'Point', 'coordinates': [-111.1541667, 33.6769444]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-SRROO-A',
#     'locName': 'ROOSEVELT LAKE - AT DAM',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060103',
#     'provider': 'STORET',
#     'sampleCnt': '245',
#     'resultCnt': '1980',
#     'bbox': [-111.1541667, 33.6769444, -111.1541667, 33.6769444]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.97',
#    'geometry': {'type': 'Point', 'coordinates': [-111.5363889, 33.5675]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-SRSAG-A',
#     'locName': 'SAGUARO LAKE - AT DAM',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '165',
#     'resultCnt': '1285',
#     'bbox': [-111.5363889, 33.5675, -111.5363889, 33.5675]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.98',
#    'geometry': {'type': 'Point', 'coordinates': [-111.4826192, 33.5631958]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-SRSAG-B',
#     'locName': 'SAGUARO LAKE - MID LAKE SITE',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '102',
#     'resultCnt': '911',
#     'bbox': [-111.4826192, 33.5631958, -111.4826192, 33.5631958]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.99',
#    'geometry': {'type': 'Point', 'coordinates': [-111.4477778, 33.5561111]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-SRSAG-C',
#     'locName': 'SAGUARO LAKE - SOUTHEAST OF BAGLEY FLAT',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '53',
#     'resultCnt': '501',
#     'bbox': [-111.4477778, 33.5561111, -111.4477778, 33.5561111]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.100',
#    'geometry': {'type': 'Point', 'coordinates': [-111.5235861, 33.5674694]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-SRSAG-NLS',
#     'locName': 'SAGUARO LAKE - 850 METERS ACROSS FROM BUTCHER JONES SITE',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '24',
#     'resultCnt': '113',
#     'bbox': [-111.5235861, 33.5674694, -111.5235861, 33.5674694]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.101',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6263889, 33.8208333]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-VRBAR-A',
#     'locName': 'BARTLETT LAKE - AT DAM',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '124',
#     'resultCnt': '823',
#     'bbox': [-111.6263889, 33.8208333, -111.6263889, 33.8208333]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.102',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6183333, 33.8525]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-VRBAR-B',
#     'locName': 'BARTLETT LAKE - MID LAKE',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '137',
#     'resultCnt': '741',
#     'bbox': [-111.6183333, 33.8525, -111.6183333, 33.8525]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.103',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6427778, 33.8936111]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-VRBAR-C',
#     'locName': 'BARTLETT LAKE - RIVERINE ZONE',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '79',
#     'resultCnt': '460',
#     'bbox': [-111.6427778, 33.8936111, -111.6427778, 33.8936111]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.104',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6364722, 33.8924722]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': '21ARIZ_WQX',
#     'orgName': 'Arizona Department Of Environmental Quality',
#     'name': '21ARIZ_WQX-VRBAR-C1',
#     'locName': 'BARTLETT LAKE - BACK OF THE LAKE',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '10',
#     'resultCnt': '100',
#     'bbox': [-111.6364722, 33.8924722, -111.6364722, 33.8924722]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.105',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6183333, 33.8525]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'AZDEQ_SW',
#     'orgName': 'AZDEQ_SW',
#     'name': 'AZDEQ_SW-10',
#     'locName': '100010',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '22',
#     'resultCnt': '383',
#     'bbox': [-111.6183333, 33.8525, -111.6183333, 33.8525]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.106',
#    'geometry': {'type': 'Point', 'coordinates': [-111.2325, 33.5961111]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'AZDEQ_SW',
#     'orgName': 'AZDEQ_SW',
#     'name': 'AZDEQ_SW-1188',
#     'locName': '101712',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '44',
#     'resultCnt': '296',
#     'bbox': [-111.2325, 33.5961111, -111.2325, 33.5961111]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.107',
#    'geometry': {'type': 'Point', 'coordinates': [-111.3491667, 33.5875]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'AZDEQ_SW',
#     'orgName': 'AZDEQ_SW',
#     'name': 'AZDEQ_SW-1345',
#     'locName': '102615',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '7',
#     'resultCnt': '95',
#     'bbox': [-111.3491667, 33.5875, -111.3491667, 33.5875]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.108',
#    'geometry': {'type': 'Point', 'coordinates': [-111.4230111, 33.5372333]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'AZDEQ_SW',
#     'orgName': 'AZDEQ_SW',
#     'name': 'AZDEQ_SW-2068',
#     'locName': '105720',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '15',
#     'resultCnt': '157',
#     'bbox': [-111.4230111, 33.5372333, -111.4230111, 33.5372333]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.109',
#    'geometry': {'type': 'Point', 'coordinates': [-112.265, 33.8502778]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'AZDEQ_SW',
#     'orgName': 'AZDEQ_SW',
#     'name': 'AZDEQ_SW-47',
#     'locName': '100067',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15070102',
#     'provider': 'STORET',
#     'sampleCnt': '51',
#     'resultCnt': '693',
#     'bbox': [-112.265, 33.8502778, -112.265, 33.8502778]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.110',
#    'geometry': {'type': 'Point', 'coordinates': [-111.3425, 33.5913889]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'AZDEQ_SW',
#     'orgName': 'AZDEQ_SW',
#     'name': 'AZDEQ_SW-523',
#     'locName': '100997',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '43',
#     'resultCnt': '291',
#     'bbox': [-111.3425, 33.5913889, -111.3425, 33.5913889]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.111',
#    'geometry': {'type': 'Point', 'coordinates': [-112.1363889, 33.3741667]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'AZDEQ_SW',
#     'orgName': 'AZDEQ_SW',
#     'name': 'AZDEQ_SW-547',
#     'locName': '101042',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '17',
#     'resultCnt': '80',
#     'bbox': [-112.1363889, 33.3741667, -112.1363889, 33.3741667]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.112',
#    'geometry': {'type': 'Point', 'coordinates': [-111.1541667, 33.6769444]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'AZDEQ_SW',
#     'orgName': 'AZDEQ_SW',
#     'name': 'AZDEQ_SW-55',
#     'locName': '100075',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060103',
#     'provider': 'STORET',
#     'sampleCnt': '49',
#     'resultCnt': '326',
#     'bbox': [-111.1541667, 33.6769444, -111.1541667, 33.6769444]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.113',
#    'geometry': {'type': 'Point', 'coordinates': [-111.9077778, 33.5113889]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'AZDEQ_SW',
#     'orgName': 'AZDEQ_SW',
#     'name': 'AZDEQ_SW-550',
#     'locName': '101045',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '30',
#     'resultCnt': '388',
#     'bbox': [-111.9077778, 33.5113889, -111.9077778, 33.5113889]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.114',
#    'geometry': {'type': 'Point', 'coordinates': [-111.5161111, 33.5722222]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'AZDEQ_SW',
#     'orgName': 'AZDEQ_SW',
#     'name': 'AZDEQ_SW-61',
#     'locName': '100081',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '60',
#     'resultCnt': '141',
#     'bbox': [-111.5161111, 33.5722222, -111.5161111, 33.5722222]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.115',
#    'geometry': {'type': 'Point', 'coordinates': [-111.9191667, 33.4330833]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'AZDEQ_SW',
#     'orgName': 'AZDEQ_SW',
#     'name': 'AZDEQ_SW-649',
#     'locName': '101315',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '7',
#     'resultCnt': '113',
#     'bbox': [-111.9191667, 33.4330833, -111.9191667, 33.4330833]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.116',
#    'geometry': {'type': 'Point', 'coordinates': [-111.4427778, 33.5527778]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'AZDEQ_SW',
#     'orgName': 'AZDEQ_SW',
#     'name': 'AZDEQ_SW-878',
#     'locName': '101697',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '19',
#     'resultCnt': '167',
#     'bbox': [-111.4427778, 33.5527778, -111.4427778, 33.5527778]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.117',
#    'geometry': {'type': 'Point', 'coordinates': [-111.6263889, 33.8208333]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'AZDEQ_SW',
#     'orgName': 'AZDEQ_SW',
#     'name': 'AZDEQ_SW-9',
#     'locName': '100009',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060203',
#     'provider': 'STORET',
#     'sampleCnt': '24',
#     'resultCnt': '397',
#     'bbox': [-111.6263889, 33.8208333, -111.6263889, 33.8208333]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.118',
#    'geometry': {'type': 'Point', 'coordinates': [-111.9196013, 33.3764843]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'NARS_WQX',
#     'orgName': 'EPA National Aquatic Resources Survey (NARS)',
#     'name': 'NARS_WQX-NLA06608-0770',
#     'locName': 'Tempe Lakes',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '5',
#     'resultCnt': '15',
#     'bbox': [-111.9196013, 33.3764843, -111.9196013, 33.3764843]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.119',
#    'geometry': {'type': 'Point', 'coordinates': [-111.5104323, 33.5565848]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'NARS_WQX',
#     'orgName': 'EPA National Aquatic Resources Survey (NARS)',
#     'name': 'NARS_WQX-NLA06608-0834',
#     'locName': 'Saguaro Lake',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '26',
#     'resultCnt': '99',
#     'bbox': [-111.5104323, 33.5565848, -111.5104323, 33.5565848]}},
#   {'type': 'Feature',
#    'id': 'dynamicSites_2656510689.120',
#    'geometry': {'type': 'Point', 'coordinates': [-111.2821257, 33.5814721]},
#    'geometry_name': 'the_geom',
#    'properties': {'orgId': 'NARS_WQX',
#     'orgName': 'EPA National Aquatic Resources Survey (NARS)',
#     'name': 'NARS_WQX-NLA06608-1602',
#     'locName': 'Apache Lake',
#     'type': 'Lake',
#     'searchType': 'Lake, Reservoir, Impoundment',
#     'huc8': '15060106',
#     'provider': 'STORET',
#     'sampleCnt': '17',
#     'resultCnt': '63',
#     'bbox': [-111.2821257, 33.5814721, -111.2821257, 33.5814721]}}],
#  'totalFeatures': 120,
#  'numberMatched': 120,
#  'numberReturned': 120,
#  'timeStamp': '2020-04-03T03:38:55.881Z',
#  'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}},
#  'bbox': [33.0797216, -113.0247216, 33.98686, -111.15361]}
